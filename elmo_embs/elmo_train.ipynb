# %%
pip install allennlp-models==v2.0.1

# %%
# !allennlp train drive/MyDrive/CollabData/elmo/collab_train_rodica_tr_prev.jsonnet --serialization-dir drive/MyDrive/CollabData/elmo/output_dir_per_tr_prev_GPU/
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# 2022-08-14 13:54:18,564 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-08-14 13:54:19,979 - INFO - allennlp.common.params - include_in_archive = None
# 2022-08-14 13:54:19,981 - INFO - allennlp.common.params - random_seed = 13370
# 2022-08-14 13:54:19,982 - INFO - allennlp.common.params - numpy_seed = 1337
# 2022-08-14 13:54:19,982 - INFO - allennlp.common.params - pytorch_seed = 133
# 2022-08-14 13:54:20,058 - INFO - allennlp.common.checks - Pytorch version: 1.7.1
# 2022-08-14 13:54:20,059 - INFO - allennlp.common.params - type = default
# 2022-08-14 13:54:20,059 - INFO - allennlp.common.params - dataset_reader.type = sharded
# 2022-08-14 13:54:20,060 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# ...
